# %%
# Import important library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize, StandardScaler, MinMaxScaler
from collections import defaultdict
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import metrics
import seaborn as sns
from sklearn.model_selection import KFold
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the input file and check the data dimension

# %%
data = pd.read_csv("german_credit.csv")
data.head(10)
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
# 5        0  no checking account                 36
# 6        0  no checking account                 24
# 7        0    0 <= ... < 200 DM                 36
# 8        0  no checking account                 12
# 9        1    0 <= ... < 200 DM                 30
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
# 5           existing credits paid back duly till now
# 6           existing credits paid back duly till now
# 7           existing credits paid back duly till now
# 8           existing credits paid back duly till now
# 9  critical account/ other credits existing (not ...
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# 3              radio/television           7882                 ... < 100 DM
# 4                     car (new)           4870                 ... < 100 DM
# 5  (vacation - does not exist?)           9055  unknown/ no savings account
# 6              radio/television           2835        500 <= ... < 1000 DM
# 7                    car (used)           6948                 ... < 100 DM
# 8           domestic appliances           3059               .. >= 1000 DM
# 9                     car (new)           5234                 ... < 100 DM
#
#     present_emp_since  installment_as_income_perc  \
# 0       .. >= 7 years                           4
# 1  1 <= ... < 4 years                           2
# 2  4 <= ... < 7 years                           2
# 3  4 <= ... < 7 years                           2
# 4  1 <= ... < 4 years                           3
# 5  1 <= ... < 4 years                           2
# 6       .. >= 7 years                           3
# 7  1 <= ... < 4 years                           2
# 8  4 <= ... < 7 years                           2
# 9          unemployed                           4
#
#                    personal_status_sex      ...       present_res_since  \
# 0                        male : single      ...                       4
# 1  female : divorced/separated/married      ...                       2
# 2                        male : single      ...                       3
# 3                        male : single      ...                       4
# 4                        male : single      ...                       4
# 5                        male : single      ...                       4
# 6                        male : single      ...                       4
# 7                        male : single      ...                       2
# 8            male : divorced/separated      ...                       4
# 9               male : married/widowed      ...                       2
#
#                                             property age  \
# 0                                        real estate  67
# 1                                        real estate  22
# 2                                        real estate  49
# 3  if not A121 : building society savings agreeme...  45
# 4                              unknown / no property  53
# 5                              unknown / no property  35
# 6  if not A121 : building society savings agreeme...  53
# 7  if not A121/A122 : car or other, not in attrib...  35
# 8                                        real estate  61
# 9  if not A121/A122 : car or other, not in attrib...  28
#
#    other_installment_plans   housing credits_this_bank  \
# 0                     none       own                 2
# 1                     none       own                 1
# 2                     none       own                 1
# 3                     none  for free                 1
# 4                     none  for free                 2
# 5                     none  for free                 1
# 6                     none       own                 1
# 7                     none      rent                 1
# 8                     none       own                 1
# 9                     none       own                 2
#
#                                                  job people_under_maintenance  \
# 0                        skilled employee / official                        1
# 1                        skilled employee / official                        1
# 2                               unskilled - resident                        2
# 3                        skilled employee / official                        2
# 4                        skilled employee / official                        2
# 5                               unskilled - resident                        2
# 6                        skilled employee / official                        1
# 7  management/ self-employed/ highly qualified em...                        1
# 8                               unskilled - resident                        1
# 9  management/ self-employed/ highly qualified em...                        1
#
#                                    telephone foreign_worker
# 0  yes, registered under the customers name             yes
# 1                                       none            yes
# 2                                       none            yes
# 3                                       none            yes
# 4                                       none            yes
# 5  yes, registered under the customers name             yes
# 6                                       none            yes
# 7  yes, registered under the customers name             yes
# 8                                       none            yes
# 9                                       none            yes
#
# [10 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# default                       1000 non-null int64
# account_check_status          1000 non-null object
# duration_in_month             1000 non-null int64
# credit_history                1000 non-null object
# purpose                       1000 non-null object
# credit_amount                 1000 non-null int64
# savings                       1000 non-null object
# present_emp_since             1000 non-null object
# installment_as_income_perc    1000 non-null int64
# personal_status_sex           1000 non-null object
# other_debtors                 1000 non-null object
# present_res_since             1000 non-null int64
# property                      1000 non-null object
# age                           1000 non-null int64
# other_installment_plans       1000 non-null object
# housing                       1000 non-null object
# credits_this_bank             1000 non-null int64
# job                           1000 non-null object
# people_under_maintenance      1000 non-null int64
# telephone                     1000 non-null object
# foreign_worker                1000 non-null object
# dtypes: int64(8), object(13)
# memory usage: 164.1+ KB

# %%
data.default.value_counts()
# Out:
# 0    700
# 1    300
# Name: default, dtype: int64

# %% [markdown]
# ### Q1 Randomly select 50% data for this use case( 1 Marks)
# ###### Hint: Use train_test_split

# %%
X = data.drop("default", axis=1)
y = data["default"]
test_size = 0.50 # taking 50:50 training and test set
seed = 7  # Random numbmer seeding for reapeatability of the code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
print(X_train.shape)
print(X_test.shape)
# Out:
# (500, 20)
# (500, 20)

# %%
# Lets build a Ensemble model but need to modify the dataset first

# %% [markdown]
# ### Q2.Prepare the model data by converting non-numeric to dummy ( 1 Marks)
# ##### Hint: Use get_dummies

# %%
# Print Shape of model data
print(data.shape)
# Out:
# (1000, 21)

# %%
#create quickaccess list with categorical variables labels
catvars = ['account_check_status', 'credit_history', 'purpose', 'savings', 'present_emp_since',
           'personal_status_sex', 'other_debtors', 'property', 'other_installment_plans', 'housing', 'job', 
           'telephone', 'foreign_worker']
#create quickaccess list with numerical variables labels
numvars = ['duration_in_month', 'credit_amount', 'installment_as_income_perc', 'present_res_since', 'age', 
           'credits_this_bank', 'people_under_maintenance']

# %%
# Numerical features range of values
for x in range(len(numvars)):
    print(numvars[x],": ", data[numvars[x]].min()," - ",data[numvars[x]].max())
# Out:
# duration_in_month :  4  -  72
# credit_amount :  250  -  18424
# installment_as_income_perc :  1  -  4
# present_res_since :  1  -  4
# age :  19  -  75
# credits_this_bank :  1  -  4
# people_under_maintenance :  1  -  2

# %%
# Standardization of numerical variables
numdata_std = pd.DataFrame(StandardScaler().fit_transform(data[numvars]))

# %% [markdown]
# ### Drop the original variables which are converted to dummy

# %%
#create dummy variables for every category of every categorical variable
dummyvars = pd.get_dummies(data[catvars], drop_first = True)

# %%
data = pd.concat([numdata_std, dummyvars, data['default']], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 49 columns):
# 0                                                                             1000 non-null float64
# 1                                                                             1000 non-null float64
# 2                                                                             1000 non-null float64
# 3                                                                             1000 non-null float64
# 4                                                                             1000 non-null float64
# 5                                                                             1000 non-null float64
# 6                                                                             1000 non-null float64
# account_check_status_< 0 DM                                                   1000 non-null uint8
# account_check_status_>= 200 DM / salary assignments for at least 1 year       1000 non-null uint8
# account_check_status_no checking account                                      1000 non-null uint8
# credit_history_critical account/ other credits existing (not at this bank)    1000 non-null uint8
# credit_history_delay in paying off in the past                                1000 non-null uint8
# credit_history_existing credits paid back duly till now                       1000 non-null uint8
# credit_history_no credits taken/ all credits paid back duly                   1000 non-null uint8
# purpose_business                                                              1000 non-null uint8
# purpose_car (new)                                                             1000 non-null uint8
# purpose_car (used)                                                            1000 non-null uint8
# purpose_domestic appliances                                                   1000 non-null uint8
# purpose_education                                                             1000 non-null uint8
# purpose_furniture/equipment                                                   1000 non-null uint8
# purpose_radio/television                                                      1000 non-null uint8
# purpose_repairs                                                               1000 non-null uint8
# purpose_retraining                                                            1000 non-null uint8
# savings_... < 100 DM                                                          1000 non-null uint8
# savings_100 <= ... < 500 DM                                                   1000 non-null uint8
# savings_500 <= ... < 1000 DM                                                  1000 non-null uint8
# savings_unknown/ no savings account                                           1000 non-null uint8
# present_emp_since_... < 1 year                                                1000 non-null uint8
# present_emp_since_1 <= ... < 4 years                                          1000 non-null uint8
# present_emp_since_4 <= ... < 7 years                                          1000 non-null uint8
# present_emp_since_unemployed                                                  1000 non-null uint8
# personal_status_sex_male : divorced/separated                                 1000 non-null uint8
# personal_status_sex_male : married/widowed                                    1000 non-null uint8
# personal_status_sex_male : single                                             1000 non-null uint8
# other_debtors_guarantor                                                       1000 non-null uint8
# other_debtors_none                                                            1000 non-null uint8
# property_if not A121/A122 : car or other, not in attribute 6                  1000 non-null uint8
# property_real estate                                                          1000 non-null uint8
# property_unknown / no property                                                1000 non-null uint8
# other_installment_plans_none                                                  1000 non-null uint8
# other_installment_plans_stores                                                1000 non-null uint8
# housing_own                                                                   1000 non-null uint8
# housing_rent                                                                  1000 non-null uint8
# job_skilled employee / official                                               1000 non-null uint8
# job_unemployed/ unskilled - non-resident                                      1000 non-null uint8
# job_unskilled - resident                                                      1000 non-null uint8
# telephone_yes, registered under the customers name                            1000 non-null uint8
# foreign_worker_yes                                                            1000 non-null uint8
# default                                                                       1000 non-null int64
# dtypes: float64(7), int64(1), uint8(41)
# memory usage: 102.6 KB

# %% [markdown]
# ### Check for highly correlated variables but don't required any treatment for this use case

# %%
corr = data.corr()
corr
# Out:
#                                                            0         1  \
# 0                                                   1.000000  0.624984
# 1                                                   0.624984  1.000000
# 2                                                   0.074749 -0.271316
# 3                                                   0.034067  0.028926
# 4                                                  -0.036136  0.032716
# 5                                                  -0.011284  0.020795
# 6                                                  -0.023834  0.017142
# account_check_status_< 0 DM                         0.022244 -0.020912
# account_check_status_>= 200 DM / salary assignm... -0.076455 -0.100510
# account_check_status_no checking account           -0.063467 -0.039485
# credit_history_critical account/ other credits ... -0.075575 -0.041807
# credit_history_delay in paying off in the past      0.136927  0.113552
# credit_history_existing credits paid back duly ... -0.069751 -0.086682
# credit_history_no credits taken/ all credits pa...  0.118077  0.147191
# purpose_business                                    0.164113  0.103016
# purpose_car (new)                                  -0.109999 -0.040793
# purpose_car (used)                                  0.144939  0.252101
# purpose_domestic appliances                        -0.044319 -0.173203
# purpose_education                                  -0.022549 -0.028875
# purpose_furniture/equipment                         0.104516  0.192893
# purpose_radio/television                           -0.062804 -0.034037
# purpose_repairs                                    -0.037212 -0.069268
# purpose_retraining                                 -0.072151 -0.069764
# savings_... < 100 DM                               -0.047228 -0.036443
# savings_100 <= ... < 500 DM                         0.051587  0.013546
# savings_500 <= ... < 1000 DM                       -0.040257 -0.064256
# savings_unknown/ no savings account                 0.071185  0.106546
# present_emp_since_... < 1 year                     -0.056792 -0.051502
# present_emp_since_1 <= ... < 4 years               -0.031920 -0.037052
# present_emp_since_4 <= ... < 7 years                0.079635  0.053755
# present_emp_since_unemployed                       -0.005156  0.086159
# personal_status_sex_male : divorced/separated       0.006415  0.033619
# personal_status_sex_male : married/widowed         -0.084418 -0.138289
# personal_status_sex_male : single                   0.121889  0.152458
# other_debtors_guarantor                            -0.039594 -0.065237
# other_debtors_none                                  0.009993 -0.004116
# property_if not A121/A122 : car or other, not i...  0.119486  0.075679
# property_real estate                               -0.242586 -0.248338
# property_unknown / no property                      0.212838  0.248922
# other_installment_plans_none                       -0.067602 -0.048292
# other_installment_plans_stores                      0.065688  0.024262
# housing_own                                        -0.075169 -0.117497
# housing_rent                                       -0.064417 -0.024611
# job_skilled employee / official                     0.055010 -0.092636
# job_unemployed/ unskilled - non-resident           -0.044043 -0.027969
# job_unskilled - resident                           -0.181203 -0.161757
# telephone_yes, registered under the customers n...  0.164718  0.276995
# foreign_worker_yes                                  0.138196  0.050050
# default                                             0.214927  0.154739
#
#                                                            2         3  \
# 0                                                   0.074749  0.034067
# 1                                                  -0.271316  0.028926
# 2                                                   1.000000  0.049302
# 3                                                   0.049302  1.000000
# 4                                                   0.058266  0.266419
# 5                                                   0.021669  0.089625
# 6                                                  -0.071207  0.042643
# account_check_status_< 0 DM                         0.046917  0.088350
# account_check_status_>= 200 DM / salary assignm... -0.041591 -0.064303
# account_check_status_no checking account            0.024961  0.001985
# credit_history_critical account/ other credits ...  0.041089  0.088460
# credit_history_delay in paying off in the past     -0.014597 -0.020351
# credit_history_existing credits paid back duly ... -0.020947 -0.081458
# credit_history_no credits taken/ all credits pa... -0.054401  0.000925
# purpose_business                                   -0.025326 -0.048899
# purpose_car (new)                                  -0.045801  0.019848
# purpose_car (used)                                 -0.094797  0.107257
# purpose_domestic appliances                         0.138552 -0.090043
# purpose_education                                   0.040204  0.027253
# purpose_furniture/equipment                        -0.030193  0.040460
# purpose_radio/television                           -0.062979 -0.006934
# purpose_repairs                                     0.019088 -0.017816
# purpose_retraining                                  0.040180  0.013390
# savings_... < 100 DM                               -0.008626 -0.089921
# savings_100 <= ... < 500 DM                        -0.015356  0.017789
# savings_500 <= ... < 1000 DM                       -0.023186  0.032702
# savings_unknown/ no savings account                 0.018367  0.080564
# present_emp_since_... < 1 year                     -0.034021 -0.164155
# present_emp_since_1 <= ... < 4 years               -0.069614 -0.140663
# present_emp_since_4 <= ... < 7 years               -0.000712 -0.031156
# present_emp_since_unemployed                       -0.049420  0.036123
# personal_status_sex_male : divorced/separated      -0.097047 -0.038473
# personal_status_sex_male : married/widowed          0.007686 -0.102684
# personal_status_sex_male : single                   0.118233  0.063639
# other_debtors_guarantor                            -0.006429 -0.028334
# other_debtors_none                                  0.013823  0.020553
# property_if not A121/A122 : car or other, not i...  0.017023 -0.041462
# property_real estate                               -0.034555 -0.085194
# property_unknown / no property                      0.044990  0.188028
# other_installment_plans_none                       -0.016139  0.016704
# other_installment_plans_stores                      0.056071 -0.054460
# housing_own                                         0.049922 -0.297547
# housing_rent                                       -0.091373  0.167285
# job_skilled employee / official                     0.042623 -0.000657
# job_unemployed/ unskilled - non-resident           -0.087834 -0.034545
# job_unskilled - resident                           -0.057237  0.009065
# telephone_yes, registered under the customers n...  0.014413  0.095359
# foreign_worker_yes                                  0.090024  0.054097
# default                                             0.072404  0.002967
#
#                                                            4         5  \
# 0                                                  -0.036136 -0.011284
# 1                                                   0.032716  0.020795
# 2                                                   0.058266  0.021669
# 3                                                   0.266419  0.089625
# 4                                                   1.000000  0.149254
# 5                                                   0.149254  1.000000
# 6                                                   0.118201  0.109667
# account_check_status_< 0 DM                        -0.011162 -0.029195
# account_check_status_>= 200 DM / salary assignm...  0.037504 -0.040213
# account_check_status_no checking account            0.062436  0.094435
# credit_history_critical account/ other credits ...  0.163681  0.501364
# credit_history_delay in paying off in the past      0.016129  0.141742
# credit_history_existing credits paid back duly ... -0.155848 -0.540354
# credit_history_no credits taken/ all credits pa... -0.022370  0.112427
# purpose_business                                   -0.001772  0.084980
# purpose_car (new)                                   0.075044  0.035845
# purpose_car (used)                                  0.050858 -0.005248
# purpose_domestic appliances                        -0.046401 -0.030706
# purpose_education                                   0.039567  0.071390
# purpose_furniture/equipment                         0.042365  0.017752
# purpose_radio/television                           -0.127657 -0.070478
# purpose_repairs                                    -0.012562 -0.061782
# purpose_retraining                                 -0.007370 -0.012159
# savings_... < 100 DM                               -0.044084  0.033909
# savings_100 <= ... < 500 DM                        -0.075302 -0.010946
# savings_500 <= ... < 1000 DM                        0.030988 -0.061599
# savings_unknown/ no savings account                 0.077811 -0.015593
# present_emp_since_... < 1 year                     -0.209967 -0.096399
# present_emp_since_1 <= ... < 4 years               -0.154975 -0.073079
# present_emp_since_4 <= ... < 7 years               -0.083520  0.037380
# present_emp_since_unemployed                        0.110562  0.012684
# personal_status_sex_male : divorced/separated       0.062430 -0.026622
# personal_status_sex_male : married/widowed         -0.145529 -0.032623
# personal_status_sex_male : single                   0.207434  0.118198
# other_debtors_guarantor                            -0.023923 -0.024682
# other_debtors_none                                  0.030822  0.022966
# property_if not A121/A122 : car or other, not i... -0.143485  0.010577
# property_real estate                                0.011538  0.008568
# property_unknown / no property                      0.206368 -0.012850
# other_installment_plans_none                       -0.035362 -0.050290
# other_installment_plans_stores                     -0.011080  0.023496
# housing_own                                         0.006553  0.041386
# housing_rent                                       -0.212620 -0.058070
# job_skilled employee / official                    -0.148283 -0.001471
# job_unemployed/ unskilled - non-resident            0.059954  0.059582
# job_unskilled - resident                            0.043712 -0.010392
# telephone_yes, registered under the customers n...  0.145259  0.065553
# foreign_worker_yes                                  0.006151  0.009717
# default                                            -0.091127 -0.045732
#
#                                                            6  \
# 0                                                  -0.023834
# 1                                                   0.017142
# 2                                                  -0.071207
# 3                                                   0.042643
# 4                                                   0.118201
# 5                                                   0.109667
# 6                                                   1.000000
# account_check_status_< 0 DM                         0.059041
# account_check_status_>= 200 DM / salary assignm... -0.008700
# account_check_status_no checking account            0.010914
# credit_history_critical account/ other credits ...  0.021765
# credit_history_delay in paying off in the past      0.042526
# credit_history_existing credits paid back duly ... -0.078339
# credit_history_no credits taken/ all credits pa...  0.011281
# purpose_business                                   -0.000327
# purpose_car (new)                                   0.102663
# purpose_car (used)                                  0.054862
# purpose_domestic appliances                        -0.082464
# purpose_education                                   0.029952
# purpose_furniture/equipment                         0.003553
# purpose_radio/television                           -0.086515
# purpose_repairs                                    -0.047201
# purpose_retraining                                  0.017701
# savings_... < 100 DM                               -0.019568
# savings_100 <= ... < 500 DM                         0.000318
# savings_500 <= ... < 1000 DM                       -0.008700
# savings_unknown/ no savings account                 0.033122
# present_emp_since_... < 1 year                     -0.048764
# present_emp_since_1 <= ... < 4 years               -0.032367
# present_emp_since_4 <= ... < 7 years                0.022084
# present_emp_since_unemployed                       -0.041363
# personal_status_sex_male : divorced/separated      -0.060222
# personal_status_sex_male : married/widowed         -0.117209
# personal_status_sex_male : single                   0.283483
# other_debtors_guarantor                             0.036589
# other_debtors_none                                 -0.005566
# property_if not A121/A122 : car or other, not i... -0.073108
# property_real estate                                0.020203
# property_unknown / no property                      0.077548
# other_installment_plans_none                       -0.072220
# other_installment_plans_stores                      0.009335
# housing_own                                        -0.027579
# housing_rent                                       -0.063033
# job_skilled employee / official                    -0.106737
# job_unemployed/ unskilled - non-resident           -0.007723
# job_unskilled - resident                            0.145066
# telephone_yes, registered under the customers n... -0.014753
# foreign_worker_yes                                 -0.077071
# default                                            -0.003015
#
#                                                     account_check_status_< 0 DM  \
# 0                                                                      0.022244
# 1                                                                     -0.020912
# 2                                                                      0.046917
# 3                                                                      0.088350
# 4                                                                     -0.011162
# 5                                                                     -0.029195
# 6                                                                      0.059041
# account_check_status_< 0 DM                                            1.000000
# account_check_status_>= 200 DM / salary assignm...                    -0.159297
# account_check_status_no checking account                              -0.495358
# credit_history_critical account/ other credits ...                    -0.065430
# credit_history_delay in paying off in the past                        -0.095859
# credit_history_existing credits paid back duly ...                     0.066396
# credit_history_no credits taken/ all credits pa...                     0.023341
# purpose_business                                                      -0.087712
# purpose_car (new)                                                      0.073527
# purpose_car (used)                                                    -0.016390
# purpose_domestic appliances                                           -0.113454
# purpose_education                                                     -0.015713
# purpose_furniture/equipment                                            0.014661
# purpose_radio/television                                               0.130479
# purpose_repairs                                                        0.035253
# purpose_retraining                                                    -0.011063
# savings_... < 100 DM                                                   0.246438
# savings_100 <= ... < 500 DM                                           -0.119659
# savings_500 <= ... < 1000 DM                                          -0.085471
# savings_unknown/ no savings account                                   -0.122593
# present_emp_since_... < 1 year                                         0.011122
# present_emp_since_1 <= ... < 4 years                                  -0.004197
# present_emp_since_4 <= ... < 7 years                                  -0.009912
# present_emp_since_unemployed                                           0.037301
# personal_status_sex_male : divorced/separated                          0.033949
# personal_status_sex_male : married/widowed                            -0.032643
# personal_status_sex_male : single                                     -0.009695
# other_debtors_guarantor                                                0.047987
# other_debtors_none                                                    -0.081198
# property_if not A121/A122 : car or other, not i...                    -0.080785
# property_real estate                                                  -0.036215
# property_unknown / no property                                         0.048476
# other_installment_plans_none                                          -0.017494
# other_installment_plans_stores                                         0.011886
# housing_own                                                           -0.125705
# housing_rent                                                           0.093310
# job_skilled employee / official                                       -0.002879
# job_unemployed/ unskilled - non-resident                              -0.000428
# job_unskilled - resident                                               0.023542
# telephone_yes, registered under the customers n...                    -0.067149
# foreign_worker_yes                                                    -0.057751
# default                                                                0.258333
#
#                                                     account_check_status_>= 200 DM / salary assignments for at least 1 year  \
# 0                                                                                           -0.076455
# 1                                                                                           -0.100510
# 2                                                                                           -0.041591
# 3                                                                                           -0.064303
# 4                                                                                            0.037504
# 5                                                                                           -0.040213
# 6                                                                                           -0.008700
# account_check_status_< 0 DM                                                                 -0.159297
# account_check_status_>= 200 DM / salary assignm...                                           1.000000
# account_check_status_no checking account                                                    -0.209080
# credit_history_critical account/ other credits ...                                          -0.004151
# credit_history_delay in paying off in the past                                              -0.036961
# credit_history_existing credits paid back duly ...                                           0.029770
# credit_history_no credits taken/ all credits pa...                                          -0.010922
# purpose_business                                                                            -0.015451
# purpose_car (new)                                                                            0.012230
# purpose_car (used)                                                                          -0.060785
# purpose_domestic appliances                                                                  0.058300
# purpose_education                                                                           -0.038890
# purpose_furniture/equipment                                                                 -0.028577
# purpose_radio/television                                                                    -0.004308
# purpose_repairs                                                                              0.009223
# purpose_retraining                                                                          -0.024711
# savings_... < 100 DM                                                                         0.025329
# savings_100 <= ... < 500 DM                                                                 -0.020162
# savings_500 <= ... < 1000 DM                                                                 0.000525
# savings_unknown/ no savings account                                                         -0.016275
# present_emp_since_... < 1 year                                                               0.045414
# present_emp_since_1 <= ... < 4 years                                                         0.014286
# present_emp_since_4 <= ... < 7 years                                                        -0.043014
# present_emp_since_unemployed                                                                -0.049597
# personal_status_sex_male : divorced/separated                                                0.053822
# personal_status_sex_male : married/widowed                                                  -0.025576
# personal_status_sex_male : single                                                           -0.012603
# other_debtors_guarantor                                                                     -0.042192
# other_debtors_none                                                                           0.040516
# property_if not A121/A122 : car or other, not i...                                           0.000734
# property_real estate                                                                         0.029581
# property_unknown / no property                                                              -0.008005
# other_installment_plans_none                                                                -0.002983
# other_installment_plans_stores                                                               0.020206
# housing_own                                                                                  0.018934
# housing_rent                                                                                -0.035183
# job_skilled employee / official                                                             -0.022932
# job_unemployed/ unskilled - non-resident                                                     0.073347
# job_unskilled - resident                                                                     0.014405
# telephone_yes, registered under the customers n...                                          -0.028955
# foreign_worker_yes                                                                          -0.036392
# default                                                                                     -0.044009
#
#                                                     account_check_status_no checking account  \
# 0                                                                                  -0.063467
# 1                                                                                  -0.039485
# 2                                                                                   0.024961
# 3                                                                                   0.001985
# 4                                                                                   0.062436
# 5                                                                                   0.094435
# 6                                                                                   0.010914
# account_check_status_< 0 DM                                                        -0.495358
# account_check_status_>= 200 DM / salary assignm...                                 -0.209080
# account_check_status_no checking account                                            1.000000
# credit_history_critical account/ other credits ...                                  0.168879
# credit_history_delay in paying off in the past                                      0.024041
# credit_history_existing credits paid back duly ...                                 -0.089471
# credit_history_no credits taken/ all credits pa...                                 -0.091486
# purpose_business                                                                   -0.008422
# purpose_car (new)                                                                  -0.058954
# purpose_car (used)                                                                  0.090342
# purpose_domestic appliances                                                         0.076027
# purpose_education                                                                  -0.009320
# purpose_furniture/equipment                                                        -0.070068
# purpose_radio/television                                                           -0.065454
# purpose_repairs                                                                    -0.013683
# purpose_retraining                                                                  0.009838
# savings_... < 100 DM                                                               -0.194841
# savings_100 <= ... < 500 DM                                                        -0.010651
# savings_500 <= ... < 1000 DM                                                        0.127847
# savings_unknown/ no savings account                                                 0.142364
# present_emp_since_... < 1 year                                                     -0.107201
# present_emp_since_1 <= ... < 4 years                                                0.023493
# present_emp_since_4 <= ... < 7 years                                                0.034786
# present_emp_since_unemployed                                                       -0.063036
# personal_status_sex_male : divorced/separated                                      -0.062913
# personal_status_sex_male : married/widowed                                         -0.022998
# personal_status_sex_male : single                                                   0.066154
# other_debtors_guarantor                                                            -0.115107
# other_debtors_none                                                                  0.110221
# property_if not A121/A122 : car or other, not i...                                  0.061674
# property_real estate                                                                0.022249
# property_unknown / no property                                                     -0.071871
# other_installment_plans_none                                                        0.048829
# other_installment_plans_stores                                                     -0.005009
# housing_own                                                                         0.104407
# housing_rent                                                                       -0.066870
# job_skilled employee / official                                                     0.075366
# job_unemployed/ unskilled - non-resident                                           -0.079080
# job_unskilled - resident                                                           -0.045023
# telephone_yes, registered under the customers n...                                  0.061825
# foreign_worker_yes                                                                  0.017108
# default                                                                            -0.322436
#
#                                                       ...     \
# 0                                                     ...
# 1                                                     ...
# 2                                                     ...
# 3                                                     ...
# 4                                                     ...
# 5                                                     ...
# 6                                                     ...
# account_check_status_< 0 DM                           ...
# account_check_status_>= 200 DM / salary assignm...    ...
# account_check_status_no checking account              ...
# credit_history_critical account/ other credits ...    ...
# credit_history_delay in paying off in the past        ...
# credit_history_existing credits paid back duly ...    ...
# credit_history_no credits taken/ all credits pa...    ...
# purpose_business                                      ...
# purpose_car (new)                                     ...
# purpose_car (used)                                    ...
# purpose_domestic appliances                           ...
# purpose_education                                     ...
# purpose_furniture/equipment                           ...
# purpose_radio/television                              ...
# purpose_repairs                                       ...
# purpose_retraining                                    ...
# savings_... < 100 DM                                  ...
# savings_100 <= ... < 500 DM                           ...
# savings_500 <= ... < 1000 DM                          ...
# savings_unknown/ no savings account                   ...
# present_emp_since_... < 1 year                        ...
# present_emp_since_1 <= ... < 4 years                  ...
# present_emp_since_4 <= ... < 7 years                  ...
# present_emp_since_unemployed                          ...
# personal_status_sex_male : divorced/separated         ...
# personal_status_sex_male : married/widowed            ...
# personal_status_sex_male : single                     ...
# other_debtors_guarantor                               ...
# other_debtors_none                                    ...
# property_if not A121/A122 : car or other, not i...    ...
# property_real estate                                  ...
# property_unknown / no property                        ...
# other_installment_plans_none                          ...
# other_installment_plans_stores                        ...
# housing_own                                           ...
# housing_rent                                          ...
# job_skilled employee / official                       ...
# job_unemployed/ unskilled - non-resident              ...
# job_unskilled - resident                              ...
# telephone_yes, registered under the customers n...    ...
# foreign_worker_yes                                    ...
# default                                               ...
#
#                                                     other_installment_plans_none  \
# 0                                                                      -0.067602
# 1                                                                      -0.048292
# 2                                                                      -0.016139
# 3                                                                       0.016704
# 4                                                                      -0.035362
# 5                                                                      -0.050290
# 6                                                                      -0.072220
# account_check_status_< 0 DM                                            -0.017494
# account_check_status_>= 200 DM / salary assignm...                     -0.002983
# account_check_status_no checking account                                0.048829
# credit_history_critical account/ other credits ...                      0.070571
# credit_history_delay in paying off in the past                         -0.051092
# credit_history_existing credits paid back duly ...                      0.105972
# credit_history_no credits taken/ all credits pa...                     -0.059804
# purpose_business                                                       -0.095155
# purpose_car (new)                                                       0.027462
# purpose_car (used)                                                      0.009791
# purpose_domestic appliances                                             0.034801
# purpose_education                                                       0.054174
# purpose_furniture/equipment                                            -0.136141
# purpose_radio/television                                                0.004446
# purpose_repairs                                                         0.029079
# purpose_retraining                                                      0.018341
# savings_... < 100 DM                                                   -0.004423
# savings_100 <= ... < 500 DM                                             0.001336
# savings_500 <= ... < 1000 DM                                           -0.002983
# savings_unknown/ no savings account                                     0.006899
# present_emp_since_... < 1 year                                         -0.006865
# present_emp_since_1 <= ... < 4 years                                    0.032868
# present_emp_since_4 <= ... < 7 years                                    0.016026
# present_emp_since_unemployed                                           -0.004987
# personal_status_sex_male : divorced/separated                           0.038913
# personal_status_sex_male : married/widowed                              0.018780
# personal_status_sex_male : single                                      -0.067502
# other_debtors_guarantor                                                -0.050097
# other_debtors_none                                                      0.032758
# property_if not A121/A122 : car or other, not i...                     -0.012268
# property_real estate                                                    0.059696
# property_unknown / no property                                         -0.066616
# other_installment_plans_none                                            1.000000
# other_installment_plans_stores                                         -0.464578
# housing_own                                                            -0.024895
# housing_rent                                                            0.069011
# job_skilled employee / official                                         0.086127
# job_unemployed/ unskilled - non-resident                                0.019133
# job_unskilled - resident                                               -0.056540
# telephone_yes, registered under the customers n...                     -0.025433
# foreign_worker_yes                                                     -0.025623
# default                                                                -0.113285
#
#                                                     other_installment_plans_stores  \
# 0                                                                         0.065688
# 1                                                                         0.024262
# 2                                                                         0.056071
# 3                                                                        -0.054460
# 4                                                                        -0.011080
# 5                                                                         0.023496
# 6                                                                         0.009335
# account_check_status_< 0 DM                                               0.011886
# account_check_status_>= 200 DM / salary assignm...                        0.020206
# account_check_status_no checking account                                 -0.005009
# credit_history_critical account/ other credits ...                       -0.049530
# credit_history_delay in paying off in the past                            0.097805
# credit_history_existing credits paid back duly ...                       -0.065418
# credit_history_no credits taken/ all credits pa...                        0.002893
# purpose_business                                                          0.070902
# purpose_car (new)                                                        -0.066940
# purpose_car (used)                                                        0.002472
# purpose_domestic appliances                                              -0.001684
# purpose_education                                                        -0.001095
# purpose_furniture/equipment                                               0.018920
# purpose_radio/television                                                  0.030595
# purpose_repairs                                                          -0.024475
# purpose_retraining                                                       -0.021163
# savings_... < 100 DM                                                      0.016021
# savings_100 <= ... < 500 DM                                              -0.013073
# savings_500 <= ... < 1000 DM                                              0.000758
# savings_unknown/ no savings account                                      -0.019564
# present_emp_since_... < 1 year                                            0.011469
# present_emp_since_1 <= ... < 4 years                                      0.030614
# present_emp_since_4 <= ... < 7 years                                     -0.027146
# present_emp_since_unemployed                                              0.040872
# personal_status_sex_male : divorced/separated                            -0.029268
# personal_status_sex_male : married/widowed                               -0.021645
# personal_status_sex_male : single                                         0.068774
# other_debtors_guarantor                                                  -0.030730
# other_debtors_none                                                        0.038574
# property_if not A121/A122 : car or other, not i...                        0.024040
# property_real estate                                                     -0.002667
# property_unknown / no property                                           -0.042387
# other_installment_plans_none                                             -0.464578
# other_installment_plans_stores                                            1.000000
# housing_own                                                               0.099115
# housing_rent                                                             -0.091369
# job_skilled employee / official                                          -0.035330
# job_unemployed/ unskilled - non-resident                                 -0.033308
# job_unskilled - resident                                                  0.030713
# telephone_yes, registered under the customers n...                        0.029003
# foreign_worker_yes                                                        0.043530
# default                                                                   0.050523
#
#                                                     housing_own  housing_rent  \
# 0                                                     -0.075169     -0.064417
# 1                                                     -0.117497     -0.024611
# 2                                                      0.049922     -0.091373
# 3                                                     -0.297547      0.167285
# 4                                                      0.006553     -0.212620
# 5                                                      0.041386     -0.058070
# 6                                                     -0.027579     -0.063033
# account_check_status_< 0 DM                           -0.125705      0.093310
# account_check_status_>= 200 DM / salary assignm...     0.018934     -0.035183
# account_check_status_no checking account               0.104407     -0.066870
# credit_history_critical account/ other credits ...     0.083011     -0.088532
# credit_history_delay in paying off in the past         0.017604     -0.043756
# credit_history_existing credits paid back duly ...    -0.043805      0.084304
# credit_history_no credits taken/ all credits pa...    -0.039709      0.037805
# purpose_business                                       0.051083     -0.012013
# purpose_car (new)                                     -0.009618     -0.011620
# purpose_car (used)                                    -0.141375      0.039160
# purpose_domestic appliances                            0.134705     -0.070414
# purpose_education                                      0.019803     -0.034465
# purpose_furniture/equipment                           -0.011288     -0.051460
# purpose_radio/television                              -0.040496      0.105700
# purpose_repairs                                        0.029317     -0.003546
# purpose_retraining                                     0.037054     -0.016877
# savings_... < 100 DM                                   0.000276     -0.010327
# savings_100 <= ... < 500 DM                           -0.017738      0.030578
# savings_500 <= ... < 1000 DM                           0.000737      0.007762
# savings_unknown/ no savings account                   -0.002739     -0.018600
# present_emp_since_... < 1 year                        -0.021299      0.112062
# present_emp_since_1 <= ... < 4 years                   0.048068      0.001758
# present_emp_since_4 <= ... < 7 years                   0.040456      0.005876
# present_emp_since_unemployed                          -0.047722     -0.033511
# personal_status_sex_male : divorced/separated          0.054265     -0.035308
# personal_status_sex_male : married/widowed             0.018387      0.058954
# personal_status_sex_male : single                      0.076736     -0.225860
# other_debtors_guarantor                                0.029113      0.019879
# other_debtors_none                                     0.002352     -0.048079
# property_if not A121/A122 : car or other, not i...     0.160934      0.003168
# property_real estate                                   0.122495      0.026215
# property_unknown / no property                        -0.476496     -0.069133
# other_installment_plans_none                          -0.024895      0.069011
# other_installment_plans_stores                         0.099115     -0.091369
# housing_own                                            1.000000     -0.735968
# housing_rent                                          -0.735968      1.000000
# job_skilled employee / official                        0.012866      0.012049
# job_unemployed/ unskilled - non-resident              -0.040480      0.018886
# job_unskilled - resident                               0.063003      0.014347
# telephone_yes, registered under the customers n...    -0.036275     -0.049524
# foreign_worker_yes                                    -0.018960     -0.032849
# default                                               -0.134589      0.092785
#
#                                                     job_skilled employee / official  \
# 0                                                                          0.055010
# 1                                                                         -0.092636
# 2                                                                          0.042623
# 3                                                                         -0.000657
# 4                                                                         -0.148283
# 5                                                                         -0.001471
# 6                                                                         -0.106737
# account_check_status_< 0 DM                                               -0.002879
# account_check_status_>= 200 DM / salary assignm...                        -0.022932
# account_check_status_no checking account                                   0.075366
# credit_history_critical account/ other credits ...                         0.001866
# credit_history_delay in paying off in the past                            -0.003217
# credit_history_existing credits paid back duly ...                         0.017015
# credit_history_no credits taken/ all credits pa...                         0.029595
# purpose_business                                                          -0.007768
# purpose_car (new)                                                         -0.085223
# purpose_car (used)                                                        -0.033321
# purpose_domestic appliances                                                0.085802
# purpose_education                                                         -0.012144
# purpose_furniture/equipment                                               -0.124785
# purpose_radio/television                                                   0.064393
# purpose_repairs                                                            0.046414
# purpose_retraining                                                        -0.058557
# savings_... < 100 DM                                                      -0.058800
# savings_100 <= ... < 500 DM                                                0.007564
# savings_500 <= ... < 1000 DM                                               0.019692
# savings_unknown/ no savings account                                        0.025230
# present_emp_since_... < 1 year                                            -0.007464
# present_emp_since_1 <= ... < 4 years                                       0.071890
# ...
# 2                                                                  -0.057237
# 3                                                                   0.009065
# 4                                                                   0.043712
# 5                                                                  -0.010392
# 6                                                                   0.145066
# account_check_status_< 0 DM                                         0.023542
# account_check_status_>= 200 DM / salary assignm...                  0.014405
# account_check_status_no checking account                           -0.045023
# credit_history_critical account/ other credits ...                 -0.003296
# credit_history_delay in paying off in the past                     -0.022944
# credit_history_existing credits paid back duly ...                  0.010018
# credit_history_no credits taken/ all credits pa...                 -0.025516
# purpose_business                                                    0.005068
# purpose_car (new)                                                   0.072041
# purpose_car (used)                                                 -0.111857
# purpose_domestic appliances                                         0.005568
# purpose_education                                                   0.044313
# purpose_furniture/equipment                                        -0.032144
# purpose_radio/television                                           -0.020778
# purpose_repairs                                                    -0.032144
# purpose_retraining                                                  0.084709
# savings_... < 100 DM                                                0.037811
# savings_100 <= ... < 500 DM                                         0.019740
# savings_500 <= ... < 1000 DM                                       -0.006174
# savings_unknown/ no savings account                                -0.049138
# present_emp_since_... < 1 year                                      0.063596
# present_emp_since_1 <= ... < 4 years                                0.064432
# present_emp_since_4 <= ... < 7 years                               -0.005276
# present_emp_since_unemployed                                       -0.118181
# personal_status_sex_male : divorced/separated                      -0.022942
# personal_status_sex_male : married/widowed                          0.031139
# personal_status_sex_male : single                                  -0.018084
# other_debtors_guarantor                                             0.063055
# other_debtors_none                                                 -0.029267
# property_if not A121/A122 : car or other, not i...                 -0.156074
# property_real estate                                                0.236681
# property_unknown / no property                                     -0.116360
# other_installment_plans_none                                       -0.056540
# other_installment_plans_stores                                      0.030713
# housing_own                                                         0.063003
# housing_rent                                                        0.014347
# job_skilled employee / official                                    -0.652438
# job_unemployed/ unskilled - non-resident                           -0.074991
# job_unskilled - resident                                            1.000000
# telephone_yes, registered under the customers n...                 -0.253720
# foreign_worker_yes                                                 -0.087412
# default                                                            -0.021822
#
#                                                     telephone_yes, registered under the customers name   \
# 0                                                                                            0.164718
# 1                                                                                            0.276995
# 2                                                                                            0.014413
# 3                                                                                            0.095359
# 4                                                                                            0.145259
# 5                                                                                            0.065553
# 6                                                                                           -0.014753
# account_check_status_< 0 DM                                                                 -0.067149
# account_check_status_>= 200 DM / salary assignm...                                          -0.028955
# account_check_status_no checking account                                                     0.061825
# credit_history_critical account/ other credits ...                                           0.043110
# credit_history_delay in paying off in the past                                               0.046384
# credit_history_existing credits paid back duly ...                                          -0.057655
# credit_history_no credits taken/ all credits pa...                                          -0.001664
# purpose_business                                                                             0.088221
# purpose_car (new)                                                                           -0.036275
# purpose_car (used)                                                                           0.136693
# purpose_domestic appliances                                                                 -0.082243
# purpose_education                                                                           -0.054017
# purpose_furniture/equipment                                                                  0.115142
# purpose_radio/television                                                                    -0.053587
# purpose_repairs                                                                             -0.015871
# purpose_retraining                                                                          -0.013724
# savings_... < 100 DM                                                                        -0.060861
# savings_100 <= ... < 500 DM                                                                 -0.024217
# savings_500 <= ... < 1000 DM                                                                 0.004596
# savings_unknown/ no savings account                                                          0.089956
# present_emp_since_... < 1 year                                                              -0.072837
# present_emp_since_1 <= ... < 4 years                                                        -0.090218
# present_emp_since_4 <= ... < 7 years                                                         0.036038
# present_emp_since_unemployed                                                                 0.084101
# personal_status_sex_male : divorced/separated                                                0.016831
# personal_status_sex_male : married/widowed                                                  -0.029388
# personal_status_sex_male : single                                                            0.080290
# other_debtors_guarantor                                                                     -0.073503
# other_debtors_none                                                                           0.067165
# property_if not A121/A122 : car or other, not i...                                           0.068685
# property_real estate                                                                        -0.162717
# property_unknown / no property                                                               0.139930
# other_installment_plans_none                                                                -0.025433
# other_installment_plans_stores                                                               0.029003
# housing_own                                                                                 -0.036275
# housing_rent                                                                                -0.049524
# job_skilled employee / official                                                             -0.061289
# job_unemployed/ unskilled - non-resident                                                    -0.040124
# job_unskilled - resident                                                                    -0.253720
# telephone_yes, registered under the customers n...                                           1.000000
# foreign_worker_yes                                                                           0.107401
# default                                                                                     -0.036466
#
#                                                     foreign_worker_yes  \
# 0                                                             0.138196
# 1                                                             0.050050
# 2                                                             0.090024
# 3                                                             0.054097
# 4                                                             0.006151
# 5                                                             0.009717
# 6                                                            -0.077071
# account_check_status_< 0 DM                                  -0.057751
# account_check_status_>= 200 DM / salary assignm...           -0.036392
# account_check_status_no checking account                      0.017108
# credit_history_critical account/ other credits ...           -0.036770
# credit_history_delay in paying off in the past                0.060888
# credit_history_existing credits paid back duly ...           -0.004140
# credit_history_no credits taken/ all credits pa...           -0.014058
# purpose_business                                              0.046343
# purpose_car (new)                                            -0.154436
# purpose_car (used)                                            0.031564
# purpose_domestic appliances                                   0.063242
# purpose_education                                            -0.006718
# purpose_furniture/equipment                                  -0.027052
# purpose_radio/television                                      0.009590
# purpose_repairs                                               0.021602
# purpose_retraining                                            0.018680
# savings_... < 100 DM                                          0.003367
# savings_100 <= ... < 500 DM                                  -0.003294
# savings_500 <= ... < 1000 DM                                  0.029022
# savings_unknown/ no savings account                          -0.003138
# present_emp_since_... < 1 year                               -0.037004
# present_emp_since_1 <= ... < 4 years                         -0.038689
# present_emp_since_4 <= ... < 7 years                         -0.007853
# present_emp_since_unemployed                                  0.050394
# personal_status_sex_male : divorced/separated                 0.020661
# personal_status_sex_male : married/widowed                   -0.047583
# personal_status_sex_male : single                            -0.028996
# other_debtors_guarantor                                      -0.097256
# other_debtors_none                                            0.119641
# property_if not A121/A122 : car or other, not i...            0.104439
# property_real estate                                         -0.112624
# property_unknown / no property                                0.054276
# other_installment_plans_none                                 -0.025623
# other_installment_plans_stores                                0.043530
# housing_own                                                  -0.018960
# housing_rent                                                 -0.032849
# job_skilled employee / official                               0.047292
# job_unemployed/ unskilled - non-resident                     -0.042834
# job_unskilled - resident                                     -0.087412
# telephone_yes, registered under the customers n...            0.107401
# foreign_worker_yes                                            1.000000
# default                                                       0.082079
#
#                                                      default
# 0                                                   0.214927
# 1                                                   0.154739
# 2                                                   0.072404
# 3                                                   0.002967
# 4                                                  -0.091127
# 5                                                  -0.045732
# 6                                                  -0.003015
# account_check_status_< 0 DM                         0.258333
# account_check_status_>= 200 DM / salary assignm... -0.044009
# account_check_status_no checking account           -0.322436
# credit_history_critical account/ other credits ... -0.181713
# credit_history_delay in paying off in the past      0.012325
# credit_history_existing credits paid back duly ...  0.043722
# credit_history_no credits taken/ all credits pa...  0.144767
# purpose_business                                    0.036129
# purpose_car (new)                                   0.096900
# purpose_car (used)                                 -0.099791
# purpose_domestic appliances                        -0.106922
# purpose_education                                   0.020828
# purpose_furniture/equipment                         0.028058
# purpose_radio/television                            0.020971
# purpose_repairs                                     0.008016
# purpose_retraining                                 -0.039281
# savings_... < 100 DM                                0.161007
# savings_100 <= ... < 500 DM                         0.022255
# savings_500 <= ... < 1000 DM                       -0.070954
# savings_unknown/ no savings account                -0.129238
# present_emp_since_... < 1 year                      0.106397
# present_emp_since_1 <= ... < 4 years                0.010603
# present_emp_since_4 <= ... < 7 years               -0.075980
# present_emp_since_unemployed                        0.039815
# personal_status_sex_male : divorced/separated       0.050063
# personal_status_sex_male : married/widowed         -0.019630
# personal_status_sex_male : single                  -0.080677
# other_debtors_guarantor                            -0.055039
# other_debtors_none                                 -0.000751
# property_if not A121/A122 : car or other, not i...  0.011121
# property_real estate                               -0.119300
# property_unknown / no property                      0.125750
# other_installment_plans_none                       -0.113285
# other_installment_plans_stores                      0.050523
# housing_own                                        -0.134589
# housing_rent                                        0.092785
# job_skilled employee / official                    -0.013559
# job_unemployed/ unskilled - non-resident            0.005951
# job_unskilled - resident                           -0.021822
# telephone_yes, registered under the customers n... -0.036466
# foreign_worker_yes                                  0.082079
# default                                             1.000000
#
# [49 rows x 49 columns]

# %%
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 3.5})
plt.figure(figsize=(50,30))
# create a mask so we only see the correlation values once
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask, 1)] = True
a = sns.heatmap(corr,mask=mask, annot=True, fmt='.2f')
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=90)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=30)

# %% [markdown]
# There are no strongly corelated features

# %% [markdown]
# ### Q3 Split Train/Test data 70:30 ratio( 1 Marks)
# ##### Hint:from sklearn.model_selection import train_test_split

# %%
X = data.drop("default", axis=1)
y = data["default"]
test_size = 0.30 # taking 70:30 training and test set
seed = 7  # Random numbmer seeding for reapeatability of the code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
print(X_train.shape)
print(X_test.shape)
# Out:
# (700, 48)
# (300, 48)

# %% [markdown]
# ### Q4 Build Random Forest Model( 1 Marks)
# #### Hint:from sklearn.ensemble import RandomForestClassifier using n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999

# %%
Rf_model = RandomForestClassifier(n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999)

# %%
Rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)

# %%
y_pred = Rf_model.predict(X_test)

# %% [markdown]
# ### Q5 Calculate Confusion Matrix and Accuracy score (1 Marks)
# ##### Hint: Use confusion_matrix and accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[201,  16],
#        [ 47,  36]])

# %%
acc=metrics.accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.79

# %%
cr=metrics.classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86       217
#            1       0.69      0.43      0.53        83
#
#    micro avg       0.79      0.79      0.79       300
#    macro avg       0.75      0.68      0.70       300
# weighted avg       0.78      0.79      0.77       300

# %% [markdown]
# ### Q6 Show the list of the features importance( 1 Marks)

# %%
print (pd.DataFrame(Rf_model.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#                                                          Imp
# 0                                                   0.086272
# 1                                                   0.116171
# 2                                                   0.041192
# 3                                                   0.039835
# 4                                                   0.091958
# 5                                                   0.020832
# 6                                                   0.016292
# account_check_status_< 0 DM                         0.034739
# account_check_status_>= 200 DM / salary assignm...  0.010112
# account_check_status_no checking account            0.056920
# credit_history_critical account/ other credits ...  0.020335
# credit_history_delay in paying off in the past      0.010089
# credit_history_existing credits paid back duly ...  0.016202
# credit_history_no credits taken/ all credits pa...  0.009035
# purpose_business                                    0.011797
# purpose_car (new)                                   0.018915
# purpose_car (used)                                  0.011905
# purpose_domestic appliances                         0.017013
# purpose_education                                   0.004442
# purpose_furniture/equipment                         0.002108
# purpose_radio/television                            0.015028
# purpose_repairs                                     0.002574
# purpose_retraining                                  0.000823
# savings_... < 100 DM                                0.020929
# savings_100 <= ... < 500 DM                         0.010425
# savings_500 <= ... < 1000 DM                        0.007235
# savings_unknown/ no savings account                 0.014891
# present_emp_since_... < 1 year                      0.018059
# present_emp_since_1 <= ... < 4 years                0.017687
# present_emp_since_4 <= ... < 7 years                0.014933
# present_emp_since_unemployed                        0.010313
# personal_status_sex_male : divorced/separated       0.007864
# personal_status_sex_male : married/widowed          0.010474
# personal_status_sex_male : single                   0.020952
# other_debtors_guarantor                             0.008296
# other_debtors_none                                  0.012030
# property_if not A121/A122 : car or other, not i...  0.017704
# property_real estate                                0.017509
# property_unknown / no property                      0.017135
# other_installment_plans_none                        0.021859
# other_installment_plans_stores                      0.006973
# housing_own                                         0.016522
# housing_rent                                        0.012242
# job_skilled employee / official                     0.019635
# job_unemployed/ unskilled - non-resident            0.004176
# job_unskilled - resident                            0.013799
# telephone_yes, registered under the customers n...  0.019920
# foreign_worker_yes                                  0.003851

# %% [markdown]
# ### Q7 K-fold cross-validation( 2 Marks)
# ##### k-fold cross validation( without stratification)
# ##### Usually k is set as 10-20 in practical settings, depends on data set size

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Use below values
num_folds = 10
seed = 77

# %%
#Validate the Random Forest model build above using k fold

# %%
X =  data.drop(['default'], axis=1)
Y =  data["default"]

# %%
kf=KFold(n_splits=5,shuffle=True,random_state=2)

# %%
kfold = model_selection.KFold(n_splits=4,random_state=0)
results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
	results.append(cv_results)
names.append(name)
	msg = "%s: %f (%f)" % (name, np.mean(cv_results), cv_results.var())
	print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
#Calculate Mean score

# %%
# Calculate score standard deviation using std()

# %% [markdown]
# # Q8 Print the confusion matrix( 1 Marks)

# %% [markdown]
# # Q9.Classification accuracy:
# percentage of correct predictions and Calculate sensitivity (or True Positive Rate or Recall) and Precision.
# ( 1 Marks)

# %% [markdown]
# # Q10.Plot Receiver Operating Characteristic (ROC) Curves( 1 Marks)

# %%
#Hint: Use roc_curve

# %% [markdown]
# ROC curve can help you to choose a threshold that balances sensitivity and specificity in a way that makes sense for your particular context

# %% [markdown]
# # Q11. Calculate AUC(the percentage of the ROC plot that is underneath the curve) - optional

# %% [markdown]
# ### Bootstrapping ( Bonus)
# ##### Given a dataset of size n, a bootstrap sample is created by sampling n instances uniformly from the data (with/without replacement)
# ##### Create a model with each bootstrap sample and validate it with the test set
# ##### Final result is calculated by averaging the accuracy of models

# %%
# Number of iterations for bootstrapping
bootstrap_iteration = 10
accuracy = []

# %%
from sklearn.utils import resample
from sklearn.metrics import accuracy_score

for i in range(bootstrap_iteration):
    X_, y_ = resample(X_train, y_train)
    rfm.fit(X_, y_)
    y_pred = rfm.predict(X_test)
    
    acc = accuracy_score(y_pred, y_test)
    accuracy.append(acc)

# %%
accuracy = np.array(accuracy)
print('Accuracy Score')
print('Avearge: ', accuracy.mean())
print('Standard deviation: ', accuracy.std())
# Out:
# Accuracy Score
# Avearge:  0.6893333333333334
# Standard deviation:  0.014966629547095768
